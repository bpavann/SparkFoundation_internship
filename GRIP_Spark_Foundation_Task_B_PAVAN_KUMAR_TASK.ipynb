# %% [markdown]
# #**DATA SCIENCE & BUSINESS ANALYTICS TASKS**

# %% [markdown]
# ***_PREDICTION USING DECISION TREE ALGORITHM_***
#
#
# **AUTHOR:-B PAVAN KUMAR**
#
# **BATCH:-GRIPNOVEMBER2021**
#
# **TASK:-6**
#
# **LEVEL:-INTERMEDIATE**
#
# **DATASET:-https://bit.ly/3kXTdox**

# %% [markdown]
# **Create the Desicion Tree  classification and visualize it graphically**

# %%
#Loading the iris.csv data set
from google.colab import files
uploded=files.upload()
# Out:
#      <input type="file" id="files-45772de8-9ada-4a2c-b0ff-92742c1632e0" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-45772de8-9ada-4a2c-b0ff-92742c1632e0">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving Iris.csv to Iris.csv

# %%
#Creating a Pandas Frame for this file and explore its content
import pandas as pd
iris=pd.read_csv("/content/Iris.csv")
print("Rows and Columns")
iris.shape
# Out:
# Rows and Columns
# (150, 6)

# %%
#describtion of data
iris.describe()
# Out:
#                Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count  150.000000     150.000000    150.000000     150.000000    150.000000
# mean    75.500000       5.843333      3.054000       3.758667      1.198667
# std     43.445368       0.828066      0.433594       1.764420      0.763161
# min      1.000000       4.300000      2.000000       1.000000      0.100000
# 25%     38.250000       5.100000      2.800000       1.600000      0.300000
# 50%     75.500000       5.800000      3.000000       4.350000      1.300000
# 75%    112.750000       6.400000      3.300000       5.100000      1.800000
# max    150.000000       7.900000      4.400000       6.900000      2.500000

# %%
#print info
iris.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             150 non-null    int64
#  1   SepalLengthCm  150 non-null    float64
#  2   SepalWidthCm   150 non-null    float64
#  3   PetalLengthCm  150 non-null    float64
#  4   PetalWidthCm   150 non-null    float64
#  5   Species        150 non-null    object
# dtypes: float64(4), int64(1), object(1)
# memory usage: 7.2+ KB

# %%
iris.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %% [markdown]
# *Few of the columns are categorical and are infered as objects. Ex: checkin_acc. Print all unique values of this column

# %%
iris['Species'].unique()
# Out:
# array(['Iris-setosa', 'Iris-versicolor', 'Iris-virginica'], dtype=object)

# %%
#is there any null?
iris.isnull().sum()
# Out:
# Id               0
# SepalLengthCm    0
# SepalWidthCm     0
# PetalLengthCm    0
# PetalWidthCm     0
# Species          0
# dtype: int64

# %%
#Histo plot of PetalLengthCM
import matplotlib.pyplot as plt
iris['PetalLengthCm'].plot.hist()
plt.show()

# %%
#Pair Plot visualization with respective to columns
import seaborn as sb
sb.pairplot(iris,hue='Species')

# %%
#Heat map using correliation.
plt.figure(figsize=(10,10))
c=iris.corr()
sb.heatmap(c,annot=True)
print(c.head())
# Out:
#                      Id  SepalLengthCm  ...  PetalLengthCm  PetalWidthCm
# Id             1.000000       0.716676  ...       0.882747      0.899759
# SepalLengthCm  0.716676       1.000000  ...       0.871754      0.817954
# SepalWidthCm  -0.397729      -0.109369  ...      -0.420516     -0.356544
# PetalLengthCm  0.882747       0.871754  ...       1.000000      0.962757
# PetalWidthCm   0.899759       0.817954  ...       0.962757      1.000000
#
# [5 rows x 5 columns]

# %% [markdown]
# Preparing And Training Data The Decision Tree Model

# %%
#Data for Training
X=iris.iloc[:,1:5]
print(X)
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# 0              5.1           3.5            1.4           0.2
# 1              4.9           3.0            1.4           0.2
# 2              4.7           3.2            1.3           0.2
# 3              4.6           3.1            1.5           0.2
# 4              5.0           3.6            1.4           0.2
# ..             ...           ...            ...           ...
# 145            6.7           3.0            5.2           2.3
# 146            6.3           2.5            5.0           1.9
# 147            6.5           3.0            5.2           2.0
# 148            6.2           3.4            5.4           2.3
# 149            5.9           3.0            5.1           1.8
#
# [150 rows x 4 columns]

# %%
y=iris["Species"]
print(y)
# Out:
# 0         Iris-setosa
# 1         Iris-setosa
# 2         Iris-setosa
# 3         Iris-setosa
# 4         Iris-setosa
#             ...
# 145    Iris-virginica
# 146    Iris-virginica
# 147    Iris-virginica
# 148    Iris-virginica
# 149    Iris-virginica
# Name: Species, Length: 150, dtype: object

# %%
#Spliting the data into 70%-30%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.3,random_state=0)

# %%
#Train a decision tree model using Entropy
from sklearn.tree import DecisionTreeClassifier
cls=DecisionTreeClassifier(criterion="entropy")
cls.fit(X_train,y_train)
print("Training Completed")
# Out:
# Training Completed

# %%
#Make predictions on test/validation data
pred_y=cls.predict(X_test)

# %%
#Print the confusion matrix, accuracy and AUC score of this model on test set
from sklearn.metrics import classification_report,confusion_matrix
print("Confusion Matrix is\n",metrics.confusion_matrix(pred_y, y_test))
print("Accuracy is", metrics.accuracy_score(pred_y,y_test))
print(classification_report(pred_y,y_test))
sb.heatmap(confusion_matrix(pred_y,y_test),annot=True)
# Out:
# Confusion Matrix is
#  [[16  0  0]
#  [ 0 17  0]
#  [ 0  1 11]]
# Accuracy is 0.9777777777777777
#                  precision    recall  f1-score   support
#
#     Iris-setosa       1.00      1.00      1.00        16
# Iris-versicolor       0.94      1.00      0.97        17
#  Iris-virginica       1.00      0.92      0.96        12
#
#        accuracy                           0.98        45
#       macro avg       0.98      0.97      0.98        45
#    weighted avg       0.98      0.98      0.98        45

# %% [markdown]
# **Visualize the tree using grapghviz and pydotplus libraries**

# %%
from sklearn.tree import export_graphviz
import pydotplus as pdot
from IPython.display import Image

export_graphviz(cls,out_file = "tree.odt", feature_names = X_train.columns, filled = True)
graph = pdot.graphviz.graph_from_dot_file("tree.odt")
graph.write_jpg("tree.png")
Image(filename = "tree.png")

# %% [markdown]
# #***THANK YOU***
